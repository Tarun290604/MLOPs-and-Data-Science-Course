# %% [markdown]
# # Module: Logging Assignments
# ## Lesson: Logging
# ### Assignment 1: Basic Logging
#
# 1. Write a Python function to create a basic logger that logs messages to a file named `app.log`.
# 2. Modify the function to log messages of levels: DEBUG, INFO, WARNING, ERROR, and CRITICAL.
#
# ### Assignment 2: Logging with Different Handlers
#
# 1. Write a Python function to create a logger that logs messages to both a file named `app.log` and the console.
# 2. Modify the function to use different logging levels for the file and console handlers.
#
# ### Assignment 3: Formatting Log Messages
#
# 1. Write a Python function to create a logger with a custom log message format that includes the timestamp, logging level, and message.
# 2. Modify the function to use different formats for the file and console handlers.
#
# ### Assignment 4: Rotating Log Files
#
# 1. Write a Python function to create a logger that uses a rotating file handler, which creates a new log file when the current log file reaches a certain size.
# 2. Modify the function to keep a specified number of backup log files.
#
# ### Assignment 5: Logging Exceptions
#
# 1. Write a Python function that logs an exception stack trace to a log file when an exception occurs.
# 2. Modify the function to log the stack trace at the ERROR level.
#
# ### Assignment 6: Contextual Logging
#
# 1. Write a Python function to create a logger that includes contextual information (e.g., function name, line number) in the log messages.
# 2. Modify the function to include additional contextual information (e.g., user ID, session ID).
#
# ### Assignment 7: Configuring Logging with a Dictionary
#
# 1. Write a Python function to configure logging using a dictionary. The configuration should include handlers for both file and console logging.
# 2. Modify the dictionary to include different logging levels and formats for each handler.
#
# ### Assignment 8: Logging in a Multi-Module Application
#
# 1. Write a Python script that sets up logging for a multi-module application. Each module should have its own logger.
# 2. Modify the script to propagate log messages from each module's logger to a root logger that handles logging to a file.
#
# ### Assignment 9: Logging Performance
#
# 1. Write a Python script to benchmark the performance of logging with different handlers (e.g., file handler, console handler, rotating file handler).
# 2. Modify the script to compare the performance of logging with and without message formatting.
#
# ### Assignment 10: Advanced Logging Configuration
#
# 1. Write a Python function to configure logging using an external configuration file (e.g., `logging.conf`). The configuration should include handlers for file and console logging.
# 2. Modify the configuration file to use different logging levels and formats for each handler.

# %%
# !pip install logging
# Out:
# Unable to create process using 'C:\Users\Tarunkumar k\Desktop\Data Science\python\venv\python.exe "C:\Users\Tarunkumar k\Desktop\Data Science\python\venv\Scripts\pip-script.py" install logging'

# %%
# 1. Write a Python function to create a basic logger that logs messages to a file named `app.log`.

import logging

logging.basicConfig(
    filename='app.log',
    level=logging.DEBUG,
    format='%(asctime)s - %(levelname)s - %(message)s',
    filemode='w'
)

# %%
# 2. Modify the function to log messages of levels: DEBUG, INFO, WARNING, ERROR, and CRITICAL.

def sample_function(x):
    logging.debug("Entered sample_function with argument: %s", x)
    
    if x < 0:
        logging.warning("Received a negative value: %d", x)
    elif x == 0:
        logging.info("Received zero, which might be a boundary case.")
    else:
        logging.info("Processing a positive value: %d", x)
    
    try:
        result = 10 / x
        logging.debug("Calculation result: %f", result)
    except ZeroDivisionError:
        logging.error("Division by zero error encountered!")
        return None

    logging.critical("This is a CRITICAL message for demonstration.")
    return result

sample_function(99)
# Out:
# 0.10101010101010101

# %%
# 1. Write a Python function to create a logger that logs messages to both a file named `app.log` and the console.

def log_creator(x='my_log'):
    logger = logging.getLogger(x)
    logger.setLevel(logging.DEBUG)

    if not logger.handlers:
        file_handler = logging.FileHandler('app1.log')
        console_handler = logging.StreamHandler()

        file_handler.setLevel(logging.DEBUG)
        console_handler.setLevel(logging.DEBUG)

        formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
        file_handler.setFormatter(formatter)
        console_handler.setFormatter(formatter)

        logger.addHandler(file_handler)
        logger.addHandler(console_handler)

    return logger

# %%
logger = log_creator()

logger.debug("This is a DEBUG message.")
logger.info("This is an INFO message.")
logger.warning("This is a WARNING message.")
logger.error("This is an ERROR message.")
logger.critical("This is a CRITICAL message.")
# Out:
# 2025-04-08 22:16:02,111 - my_log - DEBUG - This is a DEBUG message.
# 2025-04-08 22:16:02,115 - my_log - INFO - This is an INFO message.
# 2025-04-08 22:16:02,118 - my_log - WARNING - This is a WARNING message.
# 2025-04-08 22:16:02,119 - my_log - ERROR - This is an ERROR message.
# 2025-04-08 22:16:02,121 - my_log - CRITICAL - This is a CRITICAL message.

# %%
# 2. Modify the function to use different logging levels for the file and console handlers.
def create_logger(name='my_logger2'):
    logger = logging.getLogger(name)
    logger.setLevel(logging.DEBUG)  # Base logger level: logs everything

    # Prevent duplicate handlers if the logger is already configured
    if not logger.handlers:
        # File handler logs everything (DEBUG and above)
        file_handler = logging.FileHandler('app2.log')
        file_handler.setLevel(logging.DEBUG)

        # Console handler logs only WARNING and above
        console_handler = logging.StreamHandler()
        console_handler.setLevel(logging.WARNING)

        # Formatter for both handlers
        formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
        file_handler.setFormatter(formatter)
        console_handler.setFormatter(formatter)

        # Add both handlers to the logger
        logger.addHandler(file_handler)
        logger.addHandler(console_handler)

    return logger

# %%
logger = create_logger()

logger.debug("This is a DEBUG message (file only).")
logger.info("This is an INFO message (file only).")
logger.warning("This is a WARNING message (file and console).")
logger.error("This is an ERROR message (file and console).")
logger.critical("This is a CRITICAL message (file and console).")
# Out:
# 2025-04-08 22:12:57,585 - my_logger2 - WARNING - This is a WARNING message (file and console).
# 2025-04-08 22:12:57,587 - my_logger2 - ERROR - This is an ERROR message (file and console).
# 2025-04-08 22:12:57,589 - my_logger2 - CRITICAL - This is a CRITICAL message (file and console).

# %%
# 1. Write a Python function to create a logger with a custom log message format that includes the timestamp, logging level, and message.

def log_creatorfunc(name='loger'):
    logger = logging.getLogger(name)
    logger.setLevel(logging.DEBUG)
    formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
    handler = logging.StreamHandler()
    handler.setFormatter(formatter)
    logger.addHandler(handler)
    return logger

log1 = log_creatorfunc('loger1')
log1.debug("This is a DEBUG message (file only).")
log1.info("This is an INFO message (file only).")
log1.warning("This is a WARNING message (file and console).")
log1.error("This is an ERROR message (file and console).")
log1.critical("This is a CRITICAL message (file and console).")
# Out:
# 2025-04-08 22:19:51,778 - DEBUG - This is a DEBUG message (file only).
# 2025-04-08 22:19:51,780 - INFO - This is an INFO message (file only).
# 2025-04-08 22:19:51,782 - WARNING - This is a WARNING message (file and console).
# 2025-04-08 22:19:51,784 - ERROR - This is an ERROR message (file and console).
# 2025-04-08 22:19:51,785 - CRITICAL - This is a CRITICAL message (file and console).

# %%
# 2. Modify the function to use different formats for the file and console handlers.

def log_creator_func1(name='logger'):
    logger = logging.getLogger(name)
    logger.setLevel(logging.DEBUG)

    # Prevent adding handlers multiple times
    if not logger.handlers:
        # Console handler
        console_handler = logging.StreamHandler()
        console_formatter = logging.Formatter('[%(levelname)s] %(message)s')
        console_handler.setFormatter(console_formatter)
        console_handler.setLevel(logging.DEBUG)

        # File handler
        file_handler = logging.FileHandler('app2.log')
        file_formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
        file_handler.setFormatter(file_formatter)
        file_handler.setLevel(logging.DEBUG)

        # Add both handlers
        logger.addHandler(console_handler)
        logger.addHandler(file_handler)

    return logger

# %%
log1 = log_creator_func1('loger3')

log1.debug("This is a DEBUG message.")
log1.info("This is an INFO message.")
log1.warning("This is a WARNING message.")
log1.error("This is an ERROR message.")
log1.critical("This is a CRITICAL message.")
# Out:
# [DEBUG] This is a DEBUG message.
# [INFO] This is an INFO message.
# [WARNING] This is a WARNING message.
# [ERROR] This is an ERROR message.
# [CRITICAL] This is a CRITICAL message.

# %%
# 1. Write a Python function to create a logger that uses a rotating file handler, which creates a new log file when the current log file reaches a certain size.
# 2. Modify the function to keep a specified number of backup log files.
import logging
from logging.handlers import RotatingFileHandler

def create_rotating_logger(
    name='rotating_logger',
    log_file='app.log',
    max_bytes=1024*1024,  # 1 MB
    backup_count=3        # Number of backup files to keep
):
    logger = logging.getLogger(name)
    logger.setLevel(logging.DEBUG)

    if not logger.handlers:
        # Rotating file handler
        rotating_handler = RotatingFileHandler(
            log_file,
            maxBytes=max_bytes,
            backupCount=backup_count
        )
        file_formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
        rotating_handler.setFormatter(file_formatter)
        rotating_handler.setLevel(logging.DEBUG)

        # Console handler (optional, but useful for debugging)
        console_handler = logging.StreamHandler()
        console_formatter = logging.Formatter('[%(levelname)s] %(message)s')
        console_handler.setFormatter(console_formatter)
        console_handler.setLevel(logging.INFO)

        # Add handlers to logger
        logger.addHandler(rotating_handler)
        logger.addHandler(console_handler)

    return logger

# %%
logger = create_rotating_logger()

for i in range(10000):
    logger.debug(f"Log message number {i}")

# %%
import logging

# %%
# 1. Write a Python function that logs an exception stack trace to a log file when an exception occurs.
# 2. Modify the function to log the stack trace at the ERROR level.

def exception_handler(lfile='errors.log'):
    logger = logging.getLogger('exceptionlogger')
    logger.setLevel(level=logging.DEBUG)

    if not logger.handlers:
        handler = logging.FileHandler(lfile)
        formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s - %(exc_info)s')
        handler.setFormatter(formatter)
        handler.setLevel(logging.DEBUG)
        logger.addHandler(handler)
        return logger

# %%
logger = exception_handler()

def risky_operation():
    try:
        # Example error
        result = 10 / 0
    except Exception as e:
        logger.error("An exception occurred", exc_info=True)

risky_operation()

# %%
# 1. Write a Python function to create a logger that includes contextual information (e.g., function name, line number) in the log messages.

import logging

def create_contextual_logger(log_file='context.log'):
    logger = logging.getLogger('context_logger')
    logger.setLevel(logging.DEBUG)

    if not logger.handlers:
        handler = logging.FileHandler(log_file)
        formatter = logging.Formatter(
            '%(asctime)s - %(levelname)s - %(funcName)s:%(lineno)d - %(message)s'
        )
        handler.setFormatter(formatter)
        logger.addHandler(handler)

    return logger

# %%
logger = create_contextual_logger()

def test_func():
    logger.info("This is an info message with function and line number.")

test_func()

# %%
# 2. Modify the function to include additional contextual information (e.g., user ID, session ID).
def create_advanced_logger(user_id='unknown', session_id='unknown', log_file='context.log'):
    base_logger = logging.getLogger('advanced_logger')
    base_logger.setLevel(logging.DEBUG)

    if not base_logger.handlers:
        handler = logging.FileHandler(log_file)
        formatter = logging.Formatter(
            '%(asctime)s - %(levelname)s - [user:%(user_id)s session:%(session_id)s] '
            '%(funcName)s:%(lineno)d - %(message)s'
        )
        handler.setFormatter(formatter)
        base_logger.addHandler(handler)

    # Create adapter to inject context
    return logging.LoggerAdapter(base_logger, {
        'user_id': user_id,
        'session_id': session_id
    })

# %%
logger = create_advanced_logger(user_id='U123', session_id='S456')

def do_something():
    logger.warning("Something important happened.")

do_something()

# %%
# 1. Write a Python function to configure logging using a dictionary. The configuration should include handlers for both file and console logging.

import logging.config

def setup_logging():
    logging_config = {
        'version': 1,
        'disable_existing_loggers': False,
        'formatters': {
            'default': {
                'format': '%(asctime)s - %(levelname)s - %(message)s'
            }
        },
        'handlers': {
            'console': {
                'class': 'logging.StreamHandler',
                'formatter': 'default',
                'level': 'INFO',
            },
            'file': {
                'class': 'logging.FileHandler',
                'formatter': 'default',
                'filename': 'app10.log',
                'level': 'DEBUG',
            }
        },
        'root': {
            'handlers': ['console', 'file'],
            'level': 'DEBUG',
        }
    }

    logging.config.dictConfig(logging_config)

# %%
setup_logging()

logging.debug("This is a DEBUG message (file only).")
logging.info("This is an INFO message (file + console).")
logging.warning("This is a WARNING message (file + console).")
# Out:
# 2025-04-08 23:01:44,533 - INFO - This is an INFO message (file + console).
# 2025-04-08 23:01:44,534 - WARNING - This is a WARNING message (file + console).

# %%
# 2. Modify the dictionary to include different logging levels and formats for each handler.

def setup_advanced_logging():
    logging_config = {
        'version': 1,
        'disable_existing_loggers': False,
        'formatters': {
            'detailed': {
                'format': '%(asctime)s - %(name)s - %(levelname)s - %(filename)s:%(lineno)d - %(message)s'
            },
            'simple': {
                'format': '[%(levelname)s] %(message)s'
            }
        },
        'handlers': {
            'console': {
                'class': 'logging.StreamHandler',
                'formatter': 'simple',
                'level': 'WARNING',
            },
            'file': {
                'class': 'logging.FileHandler',
                'formatter': 'detailed',
                'filename': 'advanced_app.log',
                'level': 'DEBUG',
            }
        },
        'root': {
            'handlers': ['console', 'file'],
            'level': 'DEBUG',
        }
    }

    logging.config.dictConfig(logging_config)

# %%
setup_advanced_logging()

logging.debug("Debug message (file only)")
logging.info("Info message (file only)")
logging.warning("Warning message (file + console)")
logging.error("Error message (file + console)")
# Out:
# [WARNING] Warning message (file + console)
# [ERROR] Error message (file + console)

# %%
# 2. Modify the script to propagate log messages from each module's logger to a root logger that handles logging to a file.

def setup_root_logger():
    # Clear existing handlers (important in Jupyter!)
    for handler in logging.root.handlers[:]:
        logging.root.removeHandler(handler)

    logging.basicConfig(
        level=logging.DEBUG,
        format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
        handlers=[
            logging.FileHandler('app.log'),
            logging.StreamHandler()  # Print to notebook output
        ]
    )

def module_a_task():
    logger = logging.getLogger('module_a')
    logger.setLevel(logging.DEBUG)
    logger.propagate = True  # Allow bubbling to root logger

    logger.info("Module A is doing its job.")

def module_b_task():
    logger = logging.getLogger('module_b')
    logger.setLevel(logging.DEBUG)
    logger.propagate = True

    logger.warning("Module B has a warning to report.")

# %%
setup_root_logger()

module_a_task()
module_b_task()
# Out:
# 2025-04-08 23:12:51,535 - module_a - INFO - Module A is doing its job.
# 2025-04-08 23:12:51,537 - module_b - WARNING - Module B has a warning to report.

# %%
# 1. Write a Python script that sets up logging for a multi-module application. Each module should have its own logger.

def setup_module_a_logger():
    logger = logging.getLogger("module_a")
    logger.setLevel(logging.DEBUG)

    # Only add handler once (important in Jupyter)
    if not logger.handlers:
        file_handler = logging.FileHandler("module_a.log")
        file_handler.setLevel(logging.DEBUG)

        formatter = logging.Formatter("[Module A] %(asctime)s - %(levelname)s - %(message)s")
        file_handler.setFormatter(formatter)

        logger.addHandler(file_handler)
        logger.propagate = False  # Prevent sending to root logger

    return logger

def module_a():
    logger = setup_module_a_logger()
    logger.info("Module A is running.")

# %%
def setup_module_b_logger():
    logger = logging.getLogger("module_b")
    logger.setLevel(logging.DEBUG)

    if not logger.handlers:
        console_handler = logging.StreamHandler()
        console_handler.setLevel(logging.INFO)

        formatter = logging.Formatter("[Module B] %(levelname)s - %(message)s")
        console_handler.setFormatter(formatter)

        logger.addHandler(console_handler)
        logger.propagate = False

    return logger

def module_b():
    logger = setup_module_b_logger()
    logger.warning("Module B issued a warning.")

# %%
module_a()

# %%
module_b()
# Out:
# [Module B] WARNING - Module B issued a warning.

# %%
# 1. Write a Python script to benchmark the performance of logging with different handlers (e.g., file handler, console handler, rotating file handler).
# 2. Modify the script to compare the performance of logging with and without message formatting.
import timeit
from logging.handlers import RotatingFileHandler

# Number of messages to log
NUM_MESSAGES = 10000

def setup_logger(name, handler, use_format):
    logger = logging.getLogger(name)
    logger.setLevel(logging.DEBUG)
    logger.handlers.clear()  # Clear existing handlers

    if use_format:
        formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
        handler.setFormatter(formatter)

    logger.addHandler(handler)
    logger.propagate = False
    return logger

def log_messages(logger):
    for i in range(NUM_MESSAGES):
        logger.debug("This is test log message number %d", i)

# === Benchmarking Functions ===

def benchmark_file_handler(use_format=False):
    handler = logging.FileHandler("file_handler.log", mode='w')
    logger = setup_logger("file_logger", handler, use_format)
    log_messages(logger)

def benchmark_console_handler(use_format=False):
    handler = logging.StreamHandler()
    logger = setup_logger("console_logger", handler, use_format)
    log_messages(logger)

def benchmark_rotating_handler(use_format=False):
    handler = RotatingFileHandler("rotating_handler.log", maxBytes=1024*1024, backupCount=1)
    logger = setup_logger("rotating_logger", handler, use_format)
    log_messages(logger)

# === Run Benchmarks ===

print("Benchmarking... This may take a moment.\n")

for use_format in [False, True]:
    print(f"{'With' if use_format else 'Without'} Formatting:\n")

    file_time = timeit.timeit(lambda: benchmark_file_handler(use_format), number=1)
    print(f"FileHandler: {file_time:.4f} seconds")

    console_time = timeit.timeit(lambda: benchmark_console_handler(use_format), number=1)
    print(f"StreamHandler (Console): {console_time:.4f} seconds")

    rotating_time = timeit.timeit(lambda: benchmark_rotating_handler(use_format), number=1)
    print(f"RotatingFileHandler: {rotating_time:.4f} seconds")

    print("\n" + "-"*40 + "\n")
# Out:
# This is test log message number 0
# This is test log message number 1
# This is test log message number 2
# This is test log message number 3
# This is test log message number 4
# This is test log message number 5
# This is test log message number 6
# This is test log message number 7
# This is test log message number 8
# This is test log message number 9
# This is test log message number 10
# This is test log message number 11
# This is test log message number 12
# This is test log message number 13
# This is test log message number 14
# This is test log message number 15
# This is test log message number 16
# This is test log message number 17
# This is test log message number 18
# This is test log message number 19
# This is test log message number 20
# This is test log message number 21
# This is test log message number 22
# This is test log message number 23
# This is test log message number 24
# This is test log message number 25
# This is test log message number 26
# This is test log message number 27
# This is test log message number 28
# This is test log message number 29
# This is test log message number 30
# This is test log message number 31
# This is test log message number 32
# This is test log message number 33
# This is test log message number 34
# This is test log message number 35
# This is test log message number 36
# This is test log message number 37
# This is test log message number 38
# This is test log message number 39
# This is test log message number 40
# This is test log message number 41
# This is test log message number 42
# This is test log message number 43
# This is test log message number 44
# This is test log message number 45
# Benchmarking... This may take a moment.
#
# Without Formatting:
#
# FileHandler: 0.1496 seconds
# This is test log message number 46
# This is test log message number 47
# This is test log message number 48
# This is test log message number 49
# This is test log message number 50
# This is test log message number 51
# This is test log message number 52
# This is test log message number 53
# This is test log message number 54
# This is test log message number 55
# This is test log message number 56
# This is test log message number 57
# This is test log message number 58
# This is test log message number 59
# This is test log message number 60
# This is test log message number 61
# This is test log message number 62
# This is test log message number 63
# This is test log message number 64
# This is test log message number 65
# This is test log message number 66
# This is test log message number 67
# This is test log message number 68
# This is test log message number 69
# This is test log message number 70
# This is test log message number 71
# This is test log message number 72
# This is test log message number 73
# This is test log message number 74
# This is test log message number 75
# This is test log message number 76
# This is test log message number 77
# This is test log message number 78
# This is test log message number 79
# This is test log message number 80
# This is test log message number 81
# This is test log message number 82
# This is test log message number 83
# This is test log message number 84
# This is test log message number 85
# This is test log message number 86
# This is test log message number 87
# This is test log message number 88
# This is test log message number 89
# This is test log message number 90
# This is test log message number 91
# This is test log message number 92
# This is test log message number 93
# This is test log message number 94
# This is test log message number 95
# This is test log message number 96
# This is test log message number 97
# This is test log message number 98
# This is test log message number 99
# This is test log message number 100
# This is test log message number 101
# This is test log message number 102
# This is test log message number 103
# This is test log message number 104
# This is test log message number 105
# This is test log message number 106
# This is test log message number 107
# This is test log message number 108
# This is test log message number 109
# This is test log message number 110
# This is test log message number 111
# This is test log message number 112
# This is test log message number 113
# This is test log message number 114
# This is test log message number 115
# This is test log message number 116
# This is test log message number 117
# This is test log message number 118
# This is test log message number 119
# This is test log message number 120
# This is test log message number 121
# This is test log message number 122
# This is test log message number 123
# This is test log message number 124
# This is test log message number 125
# This is test log message number 126
# This is test log message number 127
# This is test log message number 128
# This is test log message number 129
# This is test log message number 130
# This is test log message number 131
# This is test log message number 132
# This is test log message number 133
# This is test log message number 134
# This is test log message number 135
# This is test log message number 136
# This is test log message number 137
# This is test log message number 138
# This is test log message number 139
# This is test log message number 140
# This is test log message number 141
# This is test log message number 142
# This is test log message number 143
# This is test log message number 144
# This is test log message number 145
# This is test log message number 146
# This is test log message number 147
# This is test log message number 148
# This is test log message number 149
# This is test log message number 150
# This is test log message number 151
# This is test log message number 152
# This is test log message number 153
# This is test log message number 154
# This is test log message number 155
# This is test log message number 156
# This is test log message number 157
# This is test log message number 158
# This is test log message number 159
# This is test log message number 160
# This is test log message number 161
# This is test log message number 162
# This is test log message number 163
# This is test log message number 164
# This is test log message number 165
# This is test log message number 166
# This is test log message number 167
# This is test log message number 168
# This is test log message number 169
# This is test log message number 170
# This is test log message number 171
# This is test log message number 172
# This is test log message number 173
# This is test log message number 174
# This is test log message number 175
# This is test log message number 176
# This is test log message number 177
# This is test log message number 178
# This is test log message number 179
# This is test log message number 180
# This is test log message number 181
# This is test log message number 182
# This is test log message number 183
# This is test log message number 184
# This is test log message number 185
# This is test log message number 186
# This is test log message number 187
# This is test log message number 188
# This is test log message number 189
# This is test log message number 190
# This is test log message number 191
# This is test log message number 192
# This is test log message number 193
# This is test log message number 194
# This is test log message number 195
# This is test log message number 196
# This is test log message number 197
# This is test log message number 198
# This is test log message number 199
# This is test log message number 200
# This is test log message number 201
# This is test log message number 202
# This is test log message number 203
# This is test log message number 204
# This is test log message number 205
# This is test log message number 206
# This is test log message number 207
# This is test log message number 208
# This is test log message number 209
# This is test log message number 210
# This is test log message number 211
# This is test log message number 212
# This is test log message number 213
# This is test log message number 214
# This is test log message number 215
# This is test log message number 216
# This is test log message number 217
# This is test log message number 218
# This is test log message number 219
# This is test log message number 220
# This is test log message number 221
# This is test log message number 222
# This is test log message number 223
# This is test log message number 224
# This is test log message number 225
# This is test log message number 226
# This is test log message number 227
# This is test log message number 228
# This is test log message number 229
# This is test log message number 230
# This is test log message number 231
# This is test log message number 232
# This is test log message number 233
# This is test log message number 234
# This is test log message number 235
# This is test log message number 236
# This is test log message number 237
# This is test log message number 238
# This is test log message number 239
# This is test log message number 240
# This is test log message number 241
# This is test log message number 242
# This is test log message number 243
# This is test log message number 244
# This is test log message number 245
# This is test log message number 246
# This is test log message number 247
# This is test log message number 248
# This is test log message number 249
# This is test log message number 250
# This is test log message number 251
# This is test log message number 252
# This is test log message number 253
# This is test log message number 254
# This is test log message number 255
# This is test log message number 256
# This is test log message number 257
# This is test log message number 258
# This is test log message number 259
# This is test log message number 260
# This is test log message number 261
# This is test log message number 262
# This is test log message number 263
# This is test log message number 264
# This is test log message number 265
# This is test log message number 266
# This is test log message number 267
# This is test log message number 268
# This is test log message number 269
# This is test log message number 270
# This is test log message number 271
# This is test log message number 272
# This is test log message number 273
# This is test log message number 274
# This is test log message number 275
# This is test log message number 276
# This is test log message number 277
# This is test log message number 278
# This is test log message number 279
# This is test log message number 280
# This is test log message number 281
# This is test log message number 282
# This is test log message number 283
# This is test log message number 284
# This is test log message number 285
# This is test log message number 286
# This is test log message number 287
# This is test log message number 288
# This is test log message number 289
# This is test log message number 290
# This is test log message number 291
# This is test log message number 292
# This is test log message number 293
# This is test log message number 294
# This is test log message number 295
# This is test log message number 296
# This is test log message number 297
# This is test log message number 298
# This is test log message number 299
# This is test log message number 300
# This is test log message number 301
# This is test log message number 302
# This is test log message number 303
# This is test log message number 304
# This is test log message number 305
# This is test log message number 306
# This is test log message number 307
# This is test log message number 308
# This is test log message number 309
# This is test log message number 310
# This is test log message number 311
# This is test log message number 312
# This is test log message number 313
# This is test log message number 314
# This is test log message number 315
# This is test log message number 316
# This is test log message number 317
# This is test log message number 318
# This is test log message number 319
# This is test log message number 320
# This is test log message number 321
# This is test log message number 322
# This is test log message number 323
# This is test log message number 324
# This is test log message number 325
# This is test log message number 326
# This is test log message number 327
# This is test log message number 328
# This is test log message number 329
# This is test log message number 330
# This is test log message number 331
# This is test log message number 332
# This is test log message number 333
# This is test log message number 334
# This is test log message number 335
# This is test log message number 336
# This is test log message number 337
# This is test log message number 338
# This is test log message number 339
# This is test log message number 340
# This is test log message number 341
# This is test log message number 342
# This is test log message number 343
# This is test log message number 344
# This is test log message number 345
# This is test log message number 346
# This is test log message number 347
# This is test log message number 348
# This is test log message number 349
# This is test log message number 350
# This is test log message number 351
# This is test log message number 352
# This is test log message number 353
# This is test log message number 354
# This is test log message number 355
# This is test log message number 356
# This is test log message number 357
# This is test log message number 358
# This is test log message number 359
# This is test log message number 360
# This is test log message number 361
# This is test log message number 362
# This is test log message number 363
# This is test log message number 364
# This is test log message number 365
# This is test log message number 366
# This is test log message number 367
# This is test log message number 368
# This is test log message number 369
# This is test log message number 370
# This is test log message number 371
# This is test log message number 372
# This is test log message number 373
# This is test log message number 374
# This is test log message number 375
# This is test log message number 376
# This is test log message number 377
# This is test log message number 378
# This is test log message number 379
# This is test log message number 380
# This is test log message number 381
# This is test log message number 382
# This is test log message number 383
# This is test log message number 384
# This is test log message number 385
# This is test log message number 386
# This is test log message number 387
# This is test log message number 388
# This is test log message number 389
# This is test log message number 390
# This is test log message number 391
# This is test log message number 392
# This is test log message number 393
# This is test log message number 394
# This is test log message number 395
# This is test log message number 396
# This is test log message number 397
# This is test log message number 398
# This is test log message number 399
# This is test log message number 400
# This is test log message number 401
# This is test log message number 402
# This is test log message number 403
# This is test log message number 404
# This is test log message number 405
# This is test log message number 406
# This is test log message number 407
# This is test log message number 408
# This is test log message number 409
# This is test log message number 410
# This is test log message number 411
# This is test log message number 412
# This is test log message number 413
# This is test log message number 414
# This is test log message number 415
# This is test log message number 416
# This is test log message number 417
# This is test log message number 418
# This is test log message number 419
# This is test log message number 420
# This is test log message number 421
# This is test log message number 422
# This is test log message number 423
# This is test log message number 424
# This is test log message number 425
# This is test log message number 426
# This is test log message number 427
# This is test log message number 428
# This is test log message number 429
# This is test log message number 430
# This is test log message number 431
# This is test log message number 432
# This is test log message number 433
# This is test log message number 434
# This is test log message number 435
# This is test log message number 436
# This is test log message number 437
# This is test log message number 438
# This is test log message number 439
# This is test log message number 440
# This is test log message number 441
# This is test log message number 442
# This is test log message number 443
# This is test log message number 444
# This is test log message number 445
# This is test log message number 446
# This is test log message number 447
# This is test log message number 448
# This is test log message number 449
# This is test log message number 450
# This is test log message number 451
# This is test log message number 452
# This is test log message number 453
# This is test log message number 454
# This is test log message number 455
# This is test log message number 456
# This is test log message number 457
# This is test log message number 458
# This is test log message number 459
# This is test log message number 460
# This is test log message number 461
# This is test log message number 462
# This is test log message number 463
# This is test log message number 464
# This is test log message number 465
# This is test log message number 466
# This is test log message number 467
# This is test log message number 468
# This is test log message number 469
# This is test log message number 470
# This is test log message number 471
# This is test log message number 472
# This is test log message number 473
# This is test log message number 474
# This is test log message number 475
# This is test log message number 476
# This is test log message number 477
# This is test log message number 478
# This is test log message number 479
# This is test log message number 480
# This is test log message number 481
# This is test log message number 482
# This is test log message number 483
# This is test log message number 484
# This is test log message number 485
# This is test log message number 486
# This is test log message number 487
# This is test log message number 488
# This is test log message number 489
# This is test log message number 490
# This is test log message number 491
# This is test log message number 492
# This is test log message number 493
# This is test log message number 494
# This is test log message number 495
# This is test log message number 496
# This is test log message number 497
# This is test log message number 498
# This is test log message number 499
# This is test log message number 500
# This is test log message number 501
# This is test log message number 502
# This is test log message number 503
# This is test log message number 504
# This is test log message number 505
# This is test log message number 506
# This is test log message number 507
# This is test log message number 508
# This is test log message number 509
# This is test log message number 510
# This is test log message number 511
# This is test log message number 512
# This is test log message number 513
# This is test log message number 514
# This is test log message number 515
# This is test log message number 516
# This is test log message number 517
# This is test log message number 518
# This is test log message number 519
# This is test log message number 520
# This is test log message number 521
# This is test log message number 522
# This is test log message number 523
# This is test log message number 524
# This is test log message number 525
# This is test log message number 526
# This is test log message number 527
# This is test log message number 528
# This is test log message number 529
# This is test log message number 530
# This is test log message number 531
# This is test log message number 532
# This is test log message number 533
# This is test log message number 534
# This is test log message number 535
# This is test log message number 536
# This is test log message number 537
# This is test log message number 538
# This is test log message number 539
# This is test log message number 540
# This is test log message number 541
# This is test log message number 542
# This is test log message number 543
# This is test log message number 544
# This is test log message number 545
# This is test log message number 546
# This is test log message number 547
# This is test log message number 548
# This is test log message number 549
# This is test log message number 550
# This is test log message number 551
# This is test log message number 552
# This is test log message number 553
# This is test log message number 554
# This is test log message number 555
# This is test log message number 556
# This is test log message number 557
# This is test log message number 558
# This is test log message number 559
# This is test log message number 560
# This is test log message number 561
# This is test log message number 562
# This is test log message number 563
# This is test log message number 564
# This is test log message number 565
# This is test log message number 566
# This is test log message number 567
# This is test log message number 568
# This is test log message number 569
# This is test log message number 570
# This is test log message number 571
# This is test log message number 572
# This is test log message number 573
# This is test log message number 574
# This is test log message number 575
# This is test log message number 576
# This is test log message number 577
# This is test log message number 578
# This is test log message number 579
# This is test log message number 580
# This is test log message number 581
# This is test log message number 582
# This is test log message number 583
# This is test log message number 584
# This is test log message number 585
# This is test log message number 586
# This is test log message number 587
# This is test log message number 588
# This is test log message number 589
# This is test log message number 590
# This is test log message number 591
# This is test log message number 592
# This is test log message number 593
# This is test log message number 594
# This is test log message number 595
# This is test log message number 596
# This is test log message number 597
# This is test log message number 598
# This is test log message number 599
# This is test log message number 600
# This is test log message number 601
# This is test log message number 602
# This is test log message number 603
# This is test log message number 604
# This is test log message number 605
# This is test log message number 606
# This is test log message number 607
# This is test log message number 608
# This is test log message number 609
# This is test log message number 610
# This is test log message number 611
# This is test log message number 612
# This is test log message number 613
# This is test log message number 614
# This is test log message number 615
# This is test log message number 616
# This is test log message number 617
# This is test log message number 618
# This is test log message number 619
# This is test log message number 620
# This is test log message number 621
# This is test log message number 622
# This is test log message number 623
# This is test log message number 624
# This is test log message number 625
# This is test log message number 626
# This is test log message number 627
# This is test log message number 628
# This is test log message number 629
# This is test log message number 630
# This is test log message number 631
# This is test log message number 632
# This is test log message number 633
# This is test log message number 634
# This is test log message number 635
# This is test log message number 636
# This is test log message number 637
# This is test log message number 638
# This is test log message number 639
# This is test log message number 640
# This is test log message number 641
# This is test log message number 642
# This is test log message number 643
# This is test log message number 644
# This is test log message number 645
# This is test log message number 646
# This is test log message number 647
# This is test log message number 648
# This is test log message number 649
# This is test log message number 650
# This is test log message number 651
# This is test log message number 652
# This is test log message number 653
# This is test log message number 654
# This is test log message number 655
# This is test log message number 656
# This is test log message number 657
# This is test log message number 658
# This is test log message number 659
# This is test log message number 660
# This is test log message number 661
# This is test log message number 662
# This is test log message number 663
# This is test log message number 664
# This is test log message number 665
# This is test log message number 666
# This is test log message number 667
# This is test log message number 668
# This is test log message number 669
# This is test log message number 670
# This is test log message number 671
# This is test log message number 672
# This is test log message number 673
# This is test log message number 674
# This is test log message number 675
# This is test log message number 676
# This is test log message number 677
# This is test log message number 678
# This is test log message number 679
# This is test log message number 680
# This is test log message number 681
# This is test log message number 682
# This is test log message number 683
# This is test log message number 684
# This is test log message number 685
# This is test log message number 686
# This is test log message number 687
# This is test log message number 688
# This is test log message number 689
# This is test log message number 690
# This is test log message number 691
# This is test log message number 692
# This is test log message number 693
# This is test log message number 694
# This is test log message number 695
# This is test log message number 696
# This is test log message number 697
# This is test log message number 698
# This is test log message number 699
# This is test log message number 700
# This is test log message number 701
# This is test log message number 702
# This is test log message number 703
# This is test log message number 704
# This is test log message number 705
# This is test log message number 706
# This is test log message number 707
# This is test log message number 708
# This is test log message number 709
# This is test log message number 710
# This is test log message number 711
# This is test log message number 712
# This is test log message number 713
# This is test log message number 714
# This is test log message number 715
# This is test log message number 716
# This is test log message number 717
# This is test log message number 718
# This is test log message number 719
# This is test log message number 720
# This is test log message number 721
# This is test log message number 722
# This is test log message number 723
# This is test log message number 724
# This is test log message number 725
# This is test log message number 726
# This is test log message number 727
# This is test log message number 728
# This is test log message number 729
# This is test log message number 730
# This is test log message number 731
# This is test log message number 732
# This is test log message number 733
# This is test log message number 734
# This is test log message number 735
# This is test log message number 736
# This is test log message number 737
# This is test log message number 738
# This is test log message number 739
# This is test log message number 740
# This is test log message number 741
# This is test log message number 742
# This is test log message number 743
# This is test log message number 744
# This is test log message number 745
# This is test log message number 746
# This is test log message number 747
# This is test log message number 748
# This is test log message number 749
# This is test log message number 750
# This is test log message number 751
# This is test log message number 752
# This is test log message number 753
# This is test log message number 754
# This is test log message number 755
# This is test log message number 756
# This is test log message number 757
# This is test log message number 758
# This is test log message number 759
# This is test log message number 760
# This is test log message number 761
# This is test log message number 762
# This is test log message number 763
# This is test log message number 764
# This is test log message number 765
# This is test log message number 766
# This is test log message number 767
# This is test log message number 768
# This is test log message number 769
# This is test log message number 770
# This is test log message number 771
# This is test log message number 772
# This is test log message number 773
# This is test log message number 774
# This is test log message number 775
# This is test log message number 776
# This is test log message number 777
# This is test log message number 778
# This is test log message number 779
# This is test log message number 780
# This is test log message number 781
# This is test log message number 782
# This is test log message number 783
# This is test log message number 784
# This is test log message number 785
# This is test log message number 786
# This is test log message number 787
# This is test log message number 788
# This is test log message number 789
# This is test log message number 790
# This is test log message number 791
# This is test log message number 792
# This is test log message number 793
# This is test log message number 794
# This is test log message number 795
# This is test log message number 796
# This is test log message number 797
# This is test log message number 798
# This is test log message number 799
# This is test log message number 800
# This is test log message number 801
# This is test log message number 802
# This is test log message number 803
# This is test log message number 804
# This is test log message number 805
# This is test log message number 806
# This is test log message number 807
# This is test log message number 808
# This is test log message number 809
# This is test log message number 810
# This is test log message number 811
# This is test log message number 812
# This is test log message number 813
# This is test log message number 814
# This is test log message number 815
# This is test log message number 816
# This is test log message number 817
# This is test log message number 818
# This is test log message number 819
# This is test log message number 820
# This is test log message number 821
# This is test log message number 822
# This is test log message number 823
# This is test log message number 824
# This is test log message number 825
# This is test log message number 826
# This is test log message number 827
# This is test log message number 828
# This is test log message number 829
# This is test log message number 830
# This is test log message number 831
# This is test log message number 832
# This is test log message number 833
# This is test log message number 834
# This is test log message number 835
# This is test log message number 836
# This is test log message number 837
# This is test log message number 838
# This is test log message number 839
# This is test log message number 840
# This is test log message number 841
# This is test log message number 842
# This is test log message number 843
# This is test log message number 844
# This is test log message number 845
# This is test log message number 846
# This is test log message number 847
# This is test log message number 848
# This is test log message number 849
# This is test log message number 850
# This is test log message number 851
# This is test log message number 852
# This is test log message number 853
# This is test log message number 854
# This is test log message number 855
# This is test log message number 856
# This is test log message number 857
# This is test log message number 858
# This is test log message number 859
# This is test log message number 860
# This is test log message number 861
# This is test log message number 862
# This is test log message number 863
# This is test log message number 864
# This is test log message number 865
# This is test log message number 866
# This is test log message number 867
# This is test log message number 868
# This is test log message number 869
# This is test log message number 870
# This is test log message number 871
# This is test log message number 872
# This is test log message number 873
# This is test log message number 874
# This is test log message number 875
# This is test log message number 876
# This is test log message number 877
# This is test log message number 878
# This is test log message number 879
# This is test log message number 880
# This is test log message number 881
# This is test log message number 882
# This is test log message number 883
# This is test log message number 884
# This is test log message number 885
# This is test log message number 886
# This is test log message number 887
# This is test log message number 888
# This is test log message number 889
# This is test log message number 890
# This is test log message number 891
# This is test log message number 892
# This is test log message number 893
# This is test log message number 894
# This is test log message number 895
# This is test log message number 896
# This is test log message number 897
# This is test log message number 898
# This is test log message number 899
# This is test log message number 900
# This is test log message number 901
# This is test log message number 902
# This is test log message number 903
# This is test log message number 904
# This is test log message number 905
# This is test log message number 906
# This is test log message number 907
# This is test log message number 908
# This is test log message number 909
# This is test log message number 910
# This is test log message number 911
# This is test log message number 912
# This is test log message number 913
# This is test log message number 914
# This is test log message number 915
# This is test log message number 916
# This is test log message number 917
# This is test log message number 918
# This is test log message number 919
# This is test log message number 920
# This is test log message number 921
# This is test log message number 922
# This is test log message number 923
# This is test log message number 924
# This is test log message number 925
# This is test log message number 926
# This is test log message number 927
# This is test log message number 928
# This is test log message number 929
# This is test log message number 930
# This is test log message number 931
# This is test log message number 932
# This is test log message number 933
# This is test log message number 934
# This is test log message number 935
# This is test log message number 936
# This is test log message number 937
# This is test log message number 938
# This is test log message number 939
# This is test log message number 940
# This is test log message number 941
# This is test log message number 942
# This is test log message number 943
# This is test log message number 944
# This is test log message number 945
# This is test log message number 946
# This is test log message number 947
# This is test log message number 948
# This is test log message number 949
# This is test log message number 950
# This is test log message number 951
# This is test log message number 952
# This is test log message number 953
# This is test log message number 954
# This is test log message number 955
# This is test log message number 956
# This is test log message number 957
# This is test log message number 958
# This is test log message number 959
# This is test log message number 960
# This is test log message number 961
# This is test log message number 962
# This is test log message number 963
# This is test log message number 964
# This is test log message number 965
# This is test log message number 966
# This is test log message number 967
# This is test log message number 968
# This is test log message number 969
# This is test log message number 970
# This is test log message number 971
# This is test log message number 972
# This is test log message number 973
# This is test log message number 974
# This is test log message number 975
# This is test log message number 976
# This is test log message number 977
# This is test log message number 978
# This is test log message number 979
# This is test log message number 980
# This is test log message number 981
# This is test log message number 982
# This is test log message number 983
# This is test log message number 984
# This is test log message number 985
# This is test log message number 986
# This is test log message number 987
# This is test log message number 988
# This is test log message number 989
# This is test log message number 990
# This is test log message number 991
# This is test log message number 992
# This is test log message number 993
# This is test log message number 994
# This is test log message number 995
# This is test log message number 996
# This is test log message number 997
# This is test log message number 998
# This is test log message number 999
# This is test log message number 1000
# This is test log message number 1001
# This is test log message number 1002
# This is test log message number 1003
# This is test log message number 1004
# This is test log message number 1005
# This is test log message number 1006
# This is test log message number 1007
# This is test log message number 1008
# This is test log message number 1009
# This is test log message number 1010
# This is test log message number 1011
# This is test log message number 1012
# This is test log message number 1013
# This is test log message number 1014
# This is test log message number 1015
# This is test log message number 1016
# This is test log message number 1017
# This is test log message number 1018
# This is test log message number 1019
# This is test log message number 1020
# This is test log message number 1021
# This is test log message number 1022
# This is test log message number 1023
# This is test log message number 1162
# This is test log message number 1163
# This is test log message number 1164
# This is test log message number 1165
# This is test log message number 1166
# This is test log message number 1167
# This is test log message number 1168
# This is test log message number 1169
# This is test log message number 1170
# This is test log message number 1171
# This is test log message number 1172
# This is test log message number 1173
# This is test log message number 1174
# This is test log message number 1175
# This is test log message number 1176
# This is test log message number 1177
# This is test log message number 1178
# This is test log message number 1179
# This is test log message number 1180
# This is test log message number 1181
# This is test log message number 1182
# This is test log message number 1183
# This is test log message number 1184
# This is test log message number 1185
# This is test log message number 1186
# This is test log message number 1187
# This is test log message number 1188
# This is test log message number 1189
# This is test log message number 1190
# This is test log message number 1191
# This is test log message number 1192
# This is test log message number 1193
# This is test log message number 1194
# This is test log message number 1195
# This is test log message number 1196
# This is test log message number 1197
# This is test log message number 1198
# This is test log message number 1199
# This is test log message number 1200
# This is test log message number 1201
# This is test log message number 1202
# This is test log message number 1203
# This is test log message number 1204
# This is test log message number 1205
# This is test log message number 1206
# This is test log message number 1207
# This is test log message number 1208
# This is test log message number 1209
# This is test log message number 1210
# This is test log message number 1211
# This is test log message number 1212
# This is test log message number 1213
# This is test log message number 1214
# This is test log message number 1215
# This is test log message number 1216
# This is test log message number 1217
# This is test log message number 1218
# This is test log message number 1219
# This is test log message number 1220
# This is test log message number 1221
# This is test log message number 1222
# This is test log message number 1223
# This is test log message number 1224
# This is test log message number 1225
# This is test log message number 1226
# This is test log message number 1227
# This is test log message number 1228
# This is test log message number 1229
# This is test log message number 1230
# This is test log message number 1231
# This is test log message number 1232
# This is test log message number 1233
# This is test log message number 1234
# This is test log message number 1235
# This is test log message number 1236
# This is test log message number 1237
# This is test log message number 1238
# This is test log message number 1239
# This is test log message number 1240
# This is test log message number 1241
# This is test log message number 1242
# This is test log message number 1243
# This is test log message number 1244
# This is test log message number 1245
# This is test log message number 1246
# This is test log message number 1247
# This is test log message number 1248
# This is test log message number 1249
# This is test log message number 1250
# This is test log message number 1251
# This is test log message number 1252
# This is test log message number 1253
# This is test log message number 1254
# This is test log message number 1255
# This is test log message number 1256
# This is test log message number 1257
# This is test log message number 1258
# This is test log message number 1259
# This is test log message number 1260
# This is test log message number 1261
# This is test log message number 1262
# This is test log message number 1263
# This is test log message number 1264
# This is test log message number 1265
# This is test log message number 1266
# This is test log message number 1267
# This is test log message number 1268
# This is test log message number 1269
# This is test log message number 1270
# This is test log message number 1271
# This is test log message number 1272
# This is test log message number 1273
# This is test log message number 1274
# This is test log message number 1275
# This is test log message number 1276
# This is test log message number 1277
# This is test log message number 1278
# This is test log message number 1279
# This is test log message number 1280
# This is test log message number 1281
# This is test log message number 1282
# This is test log message number 1283
# This is test log message number 1284
# This is test log message number 1285
# This is test log message number 1286
# This is test log message number 1287
# This is test log message number 1288
# This is test log message number 1289
# This is test log message number 1290
# This is test log message number 1291
# This is test log message number 1292
# This is test log message number 1293
# This is test log message number 1294
# This is test log message number 1295
# This is test log message number 1296
# This is test log message number 1297
# This is test log message number 1298
# This is test log message number 1299
# 2025-04-08 23:23:37,516 - console_logger - DEBUG - This is test log message number 9969
# 2025-04-08 23:23:37,518 - console_logger - DEBUG - This is test log message number 9970
# 2025-04-08 23:23:37,519 - console_logger - DEBUG - This is test log message number 9971
# 2025-04-08 23:23:37,520 - console_logger - DEBUG - This is test log message number 9972
# 2025-04-08 23:23:37,521 - console_logger - DEBUG - This is test log message number 9973
# 2025-04-08 23:23:37,523 - console_logger - DEBUG - This is test log message number 9974
# 2025-04-08 23:23:37,524 - console_logger - DEBUG - This is test log message number 9975
# 2025-04-08 23:23:37,526 - console_logger - DEBUG - This is test log message number 9976
# 2025-04-08 23:23:37,528 - console_logger - DEBUG - This is test log message number 9977
# 2025-04-08 23:23:37,530 - console_logger - DEBUG - This is test log message number 9978
# 2025-04-08 23:23:37,533 - console_logger - DEBUG - This is test log message number 9979
# 2025-04-08 23:23:37,534 - console_logger - DEBUG - This is test log message number 9980
# 2025-04-08 23:23:37,535 - console_logger - DEBUG - This is test log message number 9981
# 2025-04-08 23:23:37,536 - console_logger - DEBUG - This is test log message number 9982
# 2025-04-08 23:23:37,538 - console_logger - DEBUG - This is test log message number 9983
# 2025-04-08 23:23:37,538 - console_logger - DEBUG - This is test log message number 9984
# 2025-04-08 23:23:37,540 - console_logger - DEBUG - This is test log message number 9985
# 2025-04-08 23:23:37,542 - console_logger - DEBUG - This is test log message number 9986
# 2025-04-08 23:23:37,543 - console_logger - DEBUG - This is test log message number 9987
# 2025-04-08 23:23:37,544 - console_logger - DEBUG - This is test log message number 9988
# 2025-04-08 23:23:37,545 - console_logger - DEBUG - This is test log message number 9989
# 2025-04-08 23:23:37,546 - console_logger - DEBUG - This is test log message number 9990
# 2025-04-08 23:23:37,548 - console_logger - DEBUG - This is test log message number 9991
# 2025-04-08 23:23:37,550 - console_logger - DEBUG - This is test log message number 9992
# 2025-04-08 23:23:37,551 - console_logger - DEBUG - This is test log message number 9993
# 2025-04-08 23:23:37,552 - console_logger - DEBUG - This is test log message number 9994
# 2025-04-08 23:23:37,553 - console_logger - DEBUG - This is test log message number 9995
# 2025-04-08 23:23:37,554 - console_logger - DEBUG - This is test log message number 9996
# 2025-04-08 23:23:37,555 - console_logger - DEBUG - This is test log message number 9997
# 2025-04-08 23:23:37,556 - console_logger - DEBUG - This is test log message number 9998
# 2025-04-08 23:23:37,557 - console_logger - DEBUG - This is test log message number 9999
# StreamHandler (Console): 8.5151 seconds
# RotatingFileHandler: 0.7128 seconds
#
# ----------------------------------------

# %%
# 1. Write a Python function to configure logging using an external configuration file (e.g., `logging.conf`). The configuration should include handlers for file and console logging.
# 2. Modify the configuration file to use different logging levels and formats for each handler.
import logging
import logging.config

def setup_logging_from_config(config_path='logging.conf'):
    logging.config.fileConfig(config_path)
    logger = logging.getLogger(__name__)
    return logger

# Example usage:
logger = setup_logging_from_config()
logger.debug("This DEBUG message goes to the file.")
logger.info("This INFO message goes to both file and console.")
logger.warning("This WARNING message is shown in both.")
